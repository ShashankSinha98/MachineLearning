# %%
import gym

# %% [markdown]
# ### 1. Interacting with GYM API

# %%
# Create environment
env = gym.make('CartPole-v0')

# %%
env.reset()
# Out:
# array([-0.04704792,  0.03258928, -0.02103965,  0.02876482])

# %%
# Total no of actions available
print(env.action_space)
print(env.action_space.n)
print(env.observation_space)
print(env.action_space.sample()) # Randomly select one action
# Out:
# Discrete(2)
# 2
# Box(4,)
# 1

# %%
env.reset()
   
for t in range(200):
    random_action = env.action_space.sample()
    env.step(random_action) # Perform action
    env.render()
    
env.close()
# Out:
# c:\python\python38\lib\site-packages\gym\logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ### 2. Playing multiple game episode with random strategy

# %%
# Playing 2 game episode
for e in range(1):
    
    observation = env.reset()
    for t in range(50):
        env.render()
        random_action = env.action_space.sample()
        observation,reward,done,other_info = env.step(random_action) # Observation = new state
        print(observation,reward,done,other_info)
        if done:
            # Game episode over
            print("Game Episode %d/2, Score: %d"%(e+1,t))
            break
            
env.close()
print("All 20 episode over!")
# Out:
# [ 0.0092129  -0.24010751 -0.03520593  0.2812611 ] 1.0 False {}
# [ 0.00441075 -0.43471005 -0.02958071  0.56263561] 1.0 False {}
# [-0.00428345 -0.23918576 -0.018328    0.26078203] 1.0 False {}
# [-0.00906717 -0.43404135 -0.01311236  0.54762819] 1.0 False {}
# [-0.01774799 -0.23873766 -0.00215979  0.25084292] 1.0 False {}
# [-0.02252275 -0.04358494  0.00285706 -0.04252046] 1.0 False {}
# [-0.02339445 -0.23874774  0.00200666  0.25106253] 1.0 False {}
# [-0.0281694  -0.0436545   0.00702791 -0.04098679] 1.0 False {}
# [-0.02904249  0.15136597  0.00620817 -0.33144408] 1.0 False {}
# [-2.60151708e-02  3.46399004e-01 -4.20711529e-04 -6.22162806e-01] 1.0 False {}
# [-0.01908719  0.54152683 -0.01286397 -0.9149782 ] 1.0 False {}
# [-0.00825665  0.3465812  -0.03116353 -0.62636586] 1.0 False {}
# [-0.00132503  0.15190779 -0.04369085 -0.34365813] 1.0 False {}
# [ 0.00171313 -0.04256625 -0.05056401 -0.06506646] 1.0 False {}
# [ 0.0008618   0.15324282 -0.05186534 -0.37326416] 1.0 False {}
# [ 0.00392666 -0.04110547 -0.05933062 -0.09737531] 1.0 False {}
# [ 0.00310455  0.15481442 -0.06127813 -0.40817103] 1.0 False {}
# [ 0.00620084  0.35074927 -0.06944155 -0.71952617] 1.0 False {}
# [ 0.01321582  0.15665334 -0.08383207 -0.44948337] 1.0 False {}
# [ 0.01634889  0.35285478 -0.09282174 -0.76736976] 1.0 False {}
# [ 0.02340598  0.54912367 -0.10816914 -1.08775616] 1.0 False {}
# [ 0.03438846  0.74549277 -0.12992426 -1.412328  ] 1.0 False {}
# [ 0.04929831  0.94196369 -0.15817082 -1.74264088] 1.0 False {}
# [ 0.06813759  1.13849296 -0.19302364 -2.08006345] 1.0 False {}
# [ 0.09090745  1.33497614 -0.23462491 -2.42571201] 1.0 True {}
# Game Episode 1/2, Score: 24
# All 20 episode over!

# %% [markdown]
# ## 3. Q Learning
# - Agent Design & Neural Model

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import random

# %%
class Agent:
    
    # Constructor
    def __init__(self,state_size,action_size):
        self.state_size = state_size # 4
        self.action_size = action_size # 2 - left or right
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95 # Discount factor
        # Exploration vs Exploitation tradeoff
        # Exploration: good in beginning - helps you to try various random things
        # Explotation: good in end - sample good experiences from the past(memory)
        self.epsilon = 1.0 # 100% random exploration in beginning
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learninng_rate = 0.001
        self.model = self._create_model() 
        
        
        
    def _create_model(self):
        model = Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu'))
        model.add(Dense(24,activation='relu'))
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(loss='mse',optimizer=Adam(lr=0.001))
        return model
    
    
    
    def remember(self,state,action,reward,next_state,done):
        # Remember Past experience
        self.memory.append((state,action,reward,next_state,done))
        
        
        
    def act(self,state):
        # Sampling according to Greedy Epsion method
        if np.random.rand()<=self.epsilon:
            # Take a random action
            return random.randrange(self.action_size)
        
        # Ask NN to give me the suitable action
        return np.argmax(self.model.predict(state)[0])
    
    
    
    def train(self, batch_size=32):
        # Training using a 'Replay Buffer'
        minibatch = random.sample(self.memory,batch_size)
        
        for experience in minibatch:
            state,action,reward,next_state,done = experience
            
            if not done:
                # Game is not over, belman eqn to approx the target value of reward
                target = reward + self.gamma*np.amax(self.model.predict(next_state)[0])
            else:
                target = reward
                
            target_f = self.model.predict(state)
            target_f[0][action] = target
                
            # X = state, Y = target_f
            self.model.fit(state,target_f,epochs=1,verbose=0)
                
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
            
            
            
    def load(self,name):
        self.model.load_weightsd_weights(name)
                                         
                                         
        
    def save(self,name):
        self.model.save_weights(name)

# %% [markdown]
# ### 4. Train Deep Q-Learner Agent

# %%
n_episodes = 500
output_dir = "carpole_model/"
state_size = 4
batch_size = 32

# %%
agent = Agent(state_size=4,action_size=2)
done = False

# %%
for e in range(n_episodes):
    state = env.reset()
    state = np.reshape(state,[1,state_size])
    
    for time in range(500):
        env.render()
        action = agent.act(state) # action is 0 or 1
        next_state,reward,done,other_info = env.step(action)
        reward = reward if not done else -10
        next_state = np.reshape(next_state,[1,state_size])
        agent.remember(state,action,reward,next_state,done) # experience for the agent
        state = next_state
        
        if done:
            print("Game Episode : %d/%d, Score: %d, Exploration Rate: %.2f"%(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory) > batch_size:
        agent.train(batch_size)
        
    if e%50 == 0:
        agent.save(output_dir+"weights_%d.hdf5"%e)
    
print("Deep Q-Learnner Model Trained")
env.close()
# Out:
# Game Episode : 0/500, Score: 12, Exploration Rate: 1.00
# Game Episode : 1/500, Score: 18, Exploration Rate: 1.00
# Game Episode : 2/500, Score: 26, Exploration Rate: 1.00
# Game Episode : 3/500, Score: 32, Exploration Rate: 0.99
# Game Episode : 4/500, Score: 14, Exploration Rate: 0.99
# Game Episode : 5/500, Score: 14, Exploration Rate: 0.99
# Game Episode : 6/500, Score: 14, Exploration Rate: 0.98
# Game Episode : 7/500, Score: 16, Exploration Rate: 0.98
# Game Episode : 8/500, Score: 49, Exploration Rate: 0.97
# Game Episode : 9/500, Score: 51, Exploration Rate: 0.97
# Game Episode : 10/500, Score: 40, Exploration Rate: 0.96
# Game Episode : 11/500, Score: 8, Exploration Rate: 0.96
# Game Episode : 12/500, Score: 30, Exploration Rate: 0.95
# Game Episode : 13/500, Score: 17, Exploration Rate: 0.95
# Game Episode : 14/500, Score: 46, Exploration Rate: 0.94
# Game Episode : 15/500, Score: 22, Exploration Rate: 0.94
# Game Episode : 16/500, Score: 17, Exploration Rate: 0.93
# Game Episode : 17/500, Score: 15, Exploration Rate: 0.93
# Game Episode : 18/500, Score: 25, Exploration Rate: 0.92
# Game Episode : 19/500, Score: 18, Exploration Rate: 0.92
# Game Episode : 20/500, Score: 13, Exploration Rate: 0.91
# Game Episode : 21/500, Score: 20, Exploration Rate: 0.91
# Game Episode : 22/500, Score: 24, Exploration Rate: 0.90
# Game Episode : 23/500, Score: 16, Exploration Rate: 0.90
# Game Episode : 24/500, Score: 11, Exploration Rate: 0.90
# Game Episode : 25/500, Score: 46, Exploration Rate: 0.89
# Game Episode : 26/500, Score: 14, Exploration Rate: 0.89
# Game Episode : 27/500, Score: 27, Exploration Rate: 0.88
# Game Episode : 28/500, Score: 11, Exploration Rate: 0.88
# Game Episode : 29/500, Score: 19, Exploration Rate: 0.87
# Game Episode : 30/500, Score: 22, Exploration Rate: 0.87
# Game Episode : 31/500, Score: 17, Exploration Rate: 0.86
# Game Episode : 32/500, Score: 30, Exploration Rate: 0.86
# Game Episode : 33/500, Score: 44, Exploration Rate: 0.86
# Game Episode : 34/500, Score: 28, Exploration Rate: 0.85
# Game Episode : 35/500, Score: 75, Exploration Rate: 0.85
# Game Episode : 36/500, Score: 12, Exploration Rate: 0.84
# Game Episode : 37/500, Score: 40, Exploration Rate: 0.84
# Game Episode : 38/500, Score: 9, Exploration Rate: 0.83
# Game Episode : 39/500, Score: 51, Exploration Rate: 0.83
# Game Episode : 40/500, Score: 22, Exploration Rate: 0.83
# Game Episode : 41/500, Score: 12, Exploration Rate: 0.82
# Game Episode : 42/500, Score: 16, Exploration Rate: 0.82
# Game Episode : 43/500, Score: 12, Exploration Rate: 0.81
# Game Episode : 44/500, Score: 28, Exploration Rate: 0.81
# Game Episode : 45/500, Score: 25, Exploration Rate: 0.81
# Game Episode : 46/500, Score: 9, Exploration Rate: 0.80
# Game Episode : 47/500, Score: 13, Exploration Rate: 0.80
# Game Episode : 48/500, Score: 12, Exploration Rate: 0.79
# Game Episode : 49/500, Score: 10, Exploration Rate: 0.79
# Game Episode : 50/500, Score: 16, Exploration Rate: 0.79
# Game Episode : 51/500, Score: 17, Exploration Rate: 0.78
# Game Episode : 52/500, Score: 19, Exploration Rate: 0.78
# Game Episode : 53/500, Score: 21, Exploration Rate: 0.77
# Game Episode : 54/500, Score: 19, Exploration Rate: 0.77
# Game Episode : 55/500, Score: 15, Exploration Rate: 0.77
# Game Episode : 56/500, Score: 13, Exploration Rate: 0.76
# Game Episode : 57/500, Score: 40, Exploration Rate: 0.76
# Game Episode : 58/500, Score: 24, Exploration Rate: 0.76
# Game Episode : 59/500, Score: 22, Exploration Rate: 0.75
# Game Episode : 60/500, Score: 28, Exploration Rate: 0.75
# Game Episode : 61/500, Score: 22, Exploration Rate: 0.74
# Game Episode : 62/500, Score: 12, Exploration Rate: 0.74
# Game Episode : 63/500, Score: 25, Exploration Rate: 0.74
# Game Episode : 64/500, Score: 26, Exploration Rate: 0.73
# Game Episode : 65/500, Score: 20, Exploration Rate: 0.73
# Game Episode : 66/500, Score: 12, Exploration Rate: 0.73
# Game Episode : 67/500, Score: 11, Exploration Rate: 0.72
# Game Episode : 68/500, Score: 25, Exploration Rate: 0.72
# Game Episode : 69/500, Score: 11, Exploration Rate: 0.71
# Game Episode : 70/500, Score: 16, Exploration Rate: 0.71
# Game Episode : 71/500, Score: 13, Exploration Rate: 0.71
# Game Episode : 72/500, Score: 14, Exploration Rate: 0.70
# Game Episode : 73/500, Score: 7, Exploration Rate: 0.70
# Game Episode : 74/500, Score: 10, Exploration Rate: 0.70
# Game Episode : 75/500, Score: 22, Exploration Rate: 0.69
# Game Episode : 76/500, Score: 11, Exploration Rate: 0.69
# Game Episode : 77/500, Score: 29, Exploration Rate: 0.69
# Game Episode : 78/500, Score: 18, Exploration Rate: 0.68
# Game Episode : 79/500, Score: 10, Exploration Rate: 0.68
# Game Episode : 80/500, Score: 11, Exploration Rate: 0.68
# Game Episode : 81/500, Score: 23, Exploration Rate: 0.67
# Game Episode : 82/500, Score: 15, Exploration Rate: 0.67
# Game Episode : 83/500, Score: 27, Exploration Rate: 0.67
# Game Episode : 84/500, Score: 14, Exploration Rate: 0.66
# Game Episode : 85/500, Score: 15, Exploration Rate: 0.66
# Game Episode : 86/500, Score: 15, Exploration Rate: 0.66
# Game Episode : 87/500, Score: 55, Exploration Rate: 0.65
# Game Episode : 88/500, Score: 10, Exploration Rate: 0.65
# Game Episode : 89/500, Score: 8, Exploration Rate: 0.65
# Game Episode : 90/500, Score: 8, Exploration Rate: 0.64
# Game Episode : 91/500, Score: 10, Exploration Rate: 0.64
# Game Episode : 92/500, Score: 16, Exploration Rate: 0.64
# Game Episode : 93/500, Score: 9, Exploration Rate: 0.63
# Game Episode : 94/500, Score: 56, Exploration Rate: 0.63
# Game Episode : 95/500, Score: 26, Exploration Rate: 0.63
# Game Episode : 96/500, Score: 23, Exploration Rate: 0.62
# Game Episode : 97/500, Score: 19, Exploration Rate: 0.62
# Game Episode : 98/500, Score: 50, Exploration Rate: 0.62
# Game Episode : 99/500, Score: 32, Exploration Rate: 0.61
# Game Episode : 100/500, Score: 15, Exploration Rate: 0.61
# Game Episode : 101/500, Score: 25, Exploration Rate: 0.61
# Game Episode : 102/500, Score: 11, Exploration Rate: 0.61
# Game Episode : 103/500, Score: 12, Exploration Rate: 0.60
# Game Episode : 104/500, Score: 61, Exploration Rate: 0.60
# Game Episode : 105/500, Score: 21, Exploration Rate: 0.60
# Game Episode : 106/500, Score: 15, Exploration Rate: 0.59
# Game Episode : 107/500, Score: 22, Exploration Rate: 0.59
# Game Episode : 108/500, Score: 18, Exploration Rate: 0.59
# Game Episode : 109/500, Score: 21, Exploration Rate: 0.58
# Game Episode : 110/500, Score: 23, Exploration Rate: 0.58
# Game Episode : 111/500, Score: 36, Exploration Rate: 0.58
# Game Episode : 112/500, Score: 27, Exploration Rate: 0.58
# Game Episode : 113/500, Score: 31, Exploration Rate: 0.57
# Game Episode : 114/500, Score: 60, Exploration Rate: 0.57
# Game Episode : 115/500, Score: 47, Exploration Rate: 0.57
# Game Episode : 116/500, Score: 29, Exploration Rate: 0.56
# Game Episode : 117/500, Score: 24, Exploration Rate: 0.56
# Game Episode : 118/500, Score: 45, Exploration Rate: 0.56
# Game Episode : 119/500, Score: 44, Exploration Rate: 0.56
# Game Episode : 120/500, Score: 27, Exploration Rate: 0.55
# Game Episode : 121/500, Score: 60, Exploration Rate: 0.55
# Game Episode : 122/500, Score: 35, Exploration Rate: 0.55
# Game Episode : 123/500, Score: 25, Exploration Rate: 0.55
# Game Episode : 124/500, Score: 33, Exploration Rate: 0.54
# Game Episode : 125/500, Score: 23, Exploration Rate: 0.54
# Game Episode : 126/500, Score: 13, Exploration Rate: 0.54
# Game Episode : 127/500, Score: 26, Exploration Rate: 0.53
# Game Episode : 128/500, Score: 32, Exploration Rate: 0.53
# Game Episode : 129/500, Score: 32, Exploration Rate: 0.53
# Game Episode : 130/500, Score: 17, Exploration Rate: 0.53
# Game Episode : 131/500, Score: 21, Exploration Rate: 0.52
# Game Episode : 132/500, Score: 32, Exploration Rate: 0.52
# Game Episode : 133/500, Score: 25, Exploration Rate: 0.52
# Game Episode : 134/500, Score: 11, Exploration Rate: 0.52
# Game Episode : 135/500, Score: 33, Exploration Rate: 0.51
# Game Episode : 136/500, Score: 28, Exploration Rate: 0.51
# Game Episode : 137/500, Score: 24, Exploration Rate: 0.51
# Game Episode : 138/500, Score: 136, Exploration Rate: 0.51
# Game Episode : 139/500, Score: 144, Exploration Rate: 0.50
# Game Episode : 140/500, Score: 190, Exploration Rate: 0.50
# Game Episode : 141/500, Score: 49, Exploration Rate: 0.50
# Game Episode : 142/500, Score: 75, Exploration Rate: 0.50
# Game Episode : 143/500, Score: 29, Exploration Rate: 0.49
# Game Episode : 144/500, Score: 36, Exploration Rate: 0.49
# Game Episode : 145/500, Score: 41, Exploration Rate: 0.49
# Game Episode : 146/500, Score: 39, Exploration Rate: 0.49
# Game Episode : 147/500, Score: 53, Exploration Rate: 0.48
# Game Episode : 148/500, Score: 23, Exploration Rate: 0.48
# Game Episode : 149/500, Score: 32, Exploration Rate: 0.48
# Game Episode : 150/500, Score: 29, Exploration Rate: 0.48
# Game Episode : 151/500, Score: 38, Exploration Rate: 0.47
# Game Episode : 152/500, Score: 22, Exploration Rate: 0.47
# Game Episode : 153/500, Score: 25, Exploration Rate: 0.47
# Game Episode : 154/500, Score: 26, Exploration Rate: 0.47
# Game Episode : 155/500, Score: 87, Exploration Rate: 0.46
# Game Episode : 156/500, Score: 81, Exploration Rate: 0.46
# Game Episode : 157/500, Score: 108, Exploration Rate: 0.46
# Game Episode : 158/500, Score: 33, Exploration Rate: 0.46
# Game Episode : 159/500, Score: 137, Exploration Rate: 0.46
# Game Episode : 160/500, Score: 48, Exploration Rate: 0.45
# Game Episode : 161/500, Score: 69, Exploration Rate: 0.45
# Game Episode : 162/500, Score: 199, Exploration Rate: 0.45
# Game Episode : 163/500, Score: 92, Exploration Rate: 0.45
# Game Episode : 164/500, Score: 32, Exploration Rate: 0.44
# Game Episode : 165/500, Score: 31, Exploration Rate: 0.44
# Game Episode : 166/500, Score: 28, Exploration Rate: 0.44
# Game Episode : 167/500, Score: 22, Exploration Rate: 0.44
# Game Episode : 168/500, Score: 131, Exploration Rate: 0.44
# Game Episode : 169/500, Score: 87, Exploration Rate: 0.43
# Game Episode : 170/500, Score: 40, Exploration Rate: 0.43
# Game Episode : 171/500, Score: 39, Exploration Rate: 0.43
# Game Episode : 172/500, Score: 64, Exploration Rate: 0.43
# Game Episode : 173/500, Score: 36, Exploration Rate: 0.42
# Game Episode : 174/500, Score: 52, Exploration Rate: 0.42
# Game Episode : 175/500, Score: 111, Exploration Rate: 0.42
# Game Episode : 176/500, Score: 46, Exploration Rate: 0.42
# Game Episode : 177/500, Score: 39, Exploration Rate: 0.42
# Game Episode : 178/500, Score: 46, Exploration Rate: 0.41
# Game Episode : 179/500, Score: 42, Exploration Rate: 0.41
# Game Episode : 180/500, Score: 66, Exploration Rate: 0.41
# Game Episode : 181/500, Score: 75, Exploration Rate: 0.41
# Game Episode : 182/500, Score: 33, Exploration Rate: 0.41
# Game Episode : 183/500, Score: 25, Exploration Rate: 0.40
# Game Episode : 184/500, Score: 20, Exploration Rate: 0.40
# Game Episode : 185/500, Score: 10, Exploration Rate: 0.40
# Game Episode : 186/500, Score: 29, Exploration Rate: 0.40
# Game Episode : 187/500, Score: 37, Exploration Rate: 0.40
# Game Episode : 188/500, Score: 125, Exploration Rate: 0.39
# Game Episode : 189/500, Score: 14, Exploration Rate: 0.39
# Game Episode : 190/500, Score: 25, Exploration Rate: 0.39
# Game Episode : 191/500, Score: 199, Exploration Rate: 0.39
# Game Episode : 192/500, Score: 125, Exploration Rate: 0.39
# Game Episode : 193/500, Score: 114, Exploration Rate: 0.38
# Game Episode : 194/500, Score: 59, Exploration Rate: 0.38
# Game Episode : 195/500, Score: 144, Exploration Rate: 0.38
# Game Episode : 196/500, Score: 58, Exploration Rate: 0.38
# Game Episode : 197/500, Score: 49, Exploration Rate: 0.38
# Game Episode : 198/500, Score: 54, Exploration Rate: 0.37
# Game Episode : 199/500, Score: 100, Exploration Rate: 0.37
# Game Episode : 200/500, Score: 100, Exploration Rate: 0.37
# Game Episode : 201/500, Score: 108, Exploration Rate: 0.37
# Game Episode : 202/500, Score: 86, Exploration Rate: 0.37
# Game Episode : 203/500, Score: 72, Exploration Rate: 0.37
# Game Episode : 204/500, Score: 112, Exploration Rate: 0.36
# Game Episode : 205/500, Score: 24, Exploration Rate: 0.36
# Game Episode : 206/500, Score: 29, Exploration Rate: 0.36
# Game Episode : 207/500, Score: 59, Exploration Rate: 0.36
# Game Episode : 208/500, Score: 61, Exploration Rate: 0.36
# Game Episode : 209/500, Score: 91, Exploration Rate: 0.35
# Game Episode : 210/500, Score: 85, Exploration Rate: 0.35
# Game Episode : 211/500, Score: 41, Exploration Rate: 0.35
# Game Episode : 212/500, Score: 176, Exploration Rate: 0.35
# Game Episode : 213/500, Score: 21, Exploration Rate: 0.35
# Game Episode : 214/500, Score: 42, Exploration Rate: 0.35
# Game Episode : 215/500, Score: 48, Exploration Rate: 0.34
# Game Episode : 216/500, Score: 85, Exploration Rate: 0.34
# Game Episode : 217/500, Score: 53, Exploration Rate: 0.34
# Game Episode : 218/500, Score: 68, Exploration Rate: 0.34
# Game Episode : 219/500, Score: 60, Exploration Rate: 0.34
# Game Episode : 220/500, Score: 41, Exploration Rate: 0.34
# Game Episode : 221/500, Score: 24, Exploration Rate: 0.33
# Game Episode : 222/500, Score: 176, Exploration Rate: 0.33
# Game Episode : 223/500, Score: 73, Exploration Rate: 0.33
# Game Episode : 224/500, Score: 78, Exploration Rate: 0.33
# Game Episode : 225/500, Score: 63, Exploration Rate: 0.33
# Game Episode : 226/500, Score: 37, Exploration Rate: 0.33
# Game Episode : 227/500, Score: 123, Exploration Rate: 0.32
# Game Episode : 228/500, Score: 80, Exploration Rate: 0.32
# Game Episode : 229/500, Score: 76, Exploration Rate: 0.32
# Game Episode : 230/500, Score: 107, Exploration Rate: 0.32
# Game Episode : 231/500, Score: 106, Exploration Rate: 0.32
# Game Episode : 232/500, Score: 124, Exploration Rate: 0.32
# Game Episode : 233/500, Score: 99, Exploration Rate: 0.31
# Game Episode : 234/500, Score: 99, Exploration Rate: 0.31
# Game Episode : 235/500, Score: 105, Exploration Rate: 0.31
# Game Episode : 236/500, Score: 192, Exploration Rate: 0.31
# Game Episode : 237/500, Score: 99, Exploration Rate: 0.31
# Game Episode : 238/500, Score: 177, Exploration Rate: 0.31
# Game Episode : 239/500, Score: 199, Exploration Rate: 0.30
# Game Episode : 240/500, Score: 91, Exploration Rate: 0.30
# Game Episode : 241/500, Score: 199, Exploration Rate: 0.30
# Game Episode : 242/500, Score: 127, Exploration Rate: 0.30
# Game Episode : 243/500, Score: 199, Exploration Rate: 0.30
# Game Episode : 244/500, Score: 104, Exploration Rate: 0.30
# Game Episode : 245/500, Score: 199, Exploration Rate: 0.30
# Game Episode : 246/500, Score: 100, Exploration Rate: 0.29
# Game Episode : 247/500, Score: 95, Exploration Rate: 0.29
# Game Episode : 248/500, Score: 199, Exploration Rate: 0.29
# Game Episode : 249/500, Score: 121, Exploration Rate: 0.29
# Game Episode : 250/500, Score: 141, Exploration Rate: 0.29
# Game Episode : 251/500, Score: 129, Exploration Rate: 0.29
# Game Episode : 252/500, Score: 153, Exploration Rate: 0.29
# Game Episode : 253/500, Score: 199, Exploration Rate: 0.28
# Game Episode : 254/500, Score: 164, Exploration Rate: 0.28
# Game Episode : 255/500, Score: 160, Exploration Rate: 0.28
# Game Episode : 256/500, Score: 199, Exploration Rate: 0.28
# Game Episode : 257/500, Score: 69, Exploration Rate: 0.28
# Game Episode : 258/500, Score: 33, Exploration Rate: 0.28
# Game Episode : 259/500, Score: 127, Exploration Rate: 0.28
# Game Episode : 260/500, Score: 111, Exploration Rate: 0.27
# Game Episode : 261/500, Score: 199, Exploration Rate: 0.27
# Game Episode : 262/500, Score: 178, Exploration Rate: 0.27
# Game Episode : 263/500, Score: 199, Exploration Rate: 0.27
# Game Episode : 264/500, Score: 199, Exploration Rate: 0.27
# Game Episode : 265/500, Score: 171, Exploration Rate: 0.27
# Game Episode : 266/500, Score: 172, Exploration Rate: 0.27
# Game Episode : 267/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 268/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 269/500, Score: 111, Exploration Rate: 0.26
# Game Episode : 270/500, Score: 140, Exploration Rate: 0.26
# Game Episode : 271/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 272/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 273/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 274/500, Score: 199, Exploration Rate: 0.26
# Game Episode : 275/500, Score: 100, Exploration Rate: 0.25
# Game Episode : 276/500, Score: 199, Exploration Rate: 0.25
# Game Episode : 277/500, Score: 199, Exploration Rate: 0.25
# Game Episode : 278/500, Score: 165, Exploration Rate: 0.25
# Game Episode : 279/500, Score: 199, Exploration Rate: 0.25
# Game Episode : 280/500, Score: 199, Exploration Rate: 0.25
# Game Episode : 281/500, Score: 188, Exploration Rate: 0.25
# Game Episode : 282/500, Score: 190, Exploration Rate: 0.25
# Game Episode : 283/500, Score: 199, Exploration Rate: 0.24
# Game Episode : 284/500, Score: 170, Exploration Rate: 0.24
# Game Episode : 285/500, Score: 145, Exploration Rate: 0.24
# Game Episode : 286/500, Score: 199, Exploration Rate: 0.24
# Game Episode : 287/500, Score: 199, Exploration Rate: 0.24
# Game Episode : 288/500, Score: 32, Exploration Rate: 0.24
# Game Episode : 289/500, Score: 46, Exploration Rate: 0.24
# Game Episode : 290/500, Score: 199, Exploration Rate: 0.24
# Game Episode : 291/500, Score: 134, Exploration Rate: 0.23
# Game Episode : 292/500, Score: 110, Exploration Rate: 0.23
# Game Episode : 293/500, Score: 196, Exploration Rate: 0.23
# Game Episode : 294/500, Score: 199, Exploration Rate: 0.23
# Game Episode : 295/500, Score: 199, Exploration Rate: 0.23
# Game Episode : 296/500, Score: 169, Exploration Rate: 0.23
# Game Episode : 297/500, Score: 199, Exploration Rate: 0.23
# Game Episode : 298/500, Score: 127, Exploration Rate: 0.23
# Game Episode : 299/500, Score: 124, Exploration Rate: 0.23
# Game Episode : 300/500, Score: 182, Exploration Rate: 0.22
# Game Episode : 301/500, Score: 174, Exploration Rate: 0.22
# Game Episode : 302/500, Score: 115, Exploration Rate: 0.22
# Game Episode : 303/500, Score: 199, Exploration Rate: 0.22
# Game Episode : 304/500, Score: 199, Exploration Rate: 0.22
# Game Episode : 305/500, Score: 178, Exploration Rate: 0.22
# Game Episode : 306/500, Score: 171, Exploration Rate: 0.22
# Game Episode : 307/500, Score: 161, Exploration Rate: 0.22
# Game Episode : 308/500, Score: 199, Exploration Rate: 0.22
# Game Episode : 309/500, Score: 159, Exploration Rate: 0.21
# Game Episode : 310/500, Score: 179, Exploration Rate: 0.21
# Game Episode : 311/500, Score: 199, Exploration Rate: 0.21
# Game Episode : 312/500, Score: 176, Exploration Rate: 0.21
# Game Episode : 313/500, Score: 151, Exploration Rate: 0.21
# Game Episode : 314/500, Score: 138, Exploration Rate: 0.21
# Game Episode : 315/500, Score: 165, Exploration Rate: 0.21
# Game Episode : 316/500, Score: 199, Exploration Rate: 0.21
# Game Episode : 317/500, Score: 149, Exploration Rate: 0.21
# Game Episode : 318/500, Score: 199, Exploration Rate: 0.21
# Game Episode : 319/500, Score: 123, Exploration Rate: 0.20
# Game Episode : 320/500, Score: 198, Exploration Rate: 0.20
# Game Episode : 321/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 322/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 323/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 324/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 325/500, Score: 15, Exploration Rate: 0.20
# Game Episode : 326/500, Score: 62, Exploration Rate: 0.20
# Game Episode : 327/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 328/500, Score: 199, Exploration Rate: 0.20
# Game Episode : 329/500, Score: 185, Exploration Rate: 0.19
# Game Episode : 330/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 331/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 332/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 333/500, Score: 169, Exploration Rate: 0.19
# Game Episode : 334/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 335/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 336/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 337/500, Score: 41, Exploration Rate: 0.19
# Game Episode : 338/500, Score: 199, Exploration Rate: 0.19
# Game Episode : 339/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 340/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 341/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 342/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 343/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 344/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 345/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 346/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 347/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 348/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 349/500, Score: 199, Exploration Rate: 0.18
# Game Episode : 350/500, Score: 199, Exploration Rate: 0.17
# Game Episode : 351/500, Score: 199, Exploration Rate: 0.17
# Game Episode : 352/500, Score: 199, Exploration Rate: 0.17
# Game Episode : 353/500, Score: 199, Exploration Rate: 0.17
# Game Episode : 354/500, Score: 156, Exploration Rate: 0.17
# Game Episode : 355/500, Score: 199, Exploration Rate: 0.17
# Game Episode : 356/500, Score: 184, Exploration Rate: 0.17
# Game Episode : 357/500, Score: 153, Exploration Rate: 0.17
# Game Episode : 358/500, Score: 68, Exploration Rate: 0.17
# Game Episode : 359/500, Score: 55, Exploration Rate: 0.17
# Game Episode : 360/500, Score: 64, Exploration Rate: 0.17
# Game Episode : 361/500, Score: 65, Exploration Rate: 0.17
# Game Episode : 362/500, Score: 71, Exploration Rate: 0.16
# Game Episode : 363/500, Score: 9, Exploration Rate: 0.16
# Game Episode : 364/500, Score: 10, Exploration Rate: 0.16
# Game Episode : 365/500, Score: 47, Exploration Rate: 0.16
# Game Episode : 366/500, Score: 173, Exploration Rate: 0.16
# Game Episode : 367/500, Score: 58, Exploration Rate: 0.16
# Game Episode : 368/500, Score: 50, Exploration Rate: 0.16
# Game Episode : 369/500, Score: 46, Exploration Rate: 0.16
# Game Episode : 370/500, Score: 31, Exploration Rate: 0.16
# Game Episode : 371/500, Score: 23, Exploration Rate: 0.16
# Game Episode : 372/500, Score: 10, Exploration Rate: 0.16
# Game Episode : 373/500, Score: 11, Exploration Rate: 0.16
# Game Episode : 374/500, Score: 131, Exploration Rate: 0.15
# Game Episode : 375/500, Score: 42, Exploration Rate: 0.15
# Game Episode : 376/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 377/500, Score: 9, Exploration Rate: 0.15
# Game Episode : 378/500, Score: 9, Exploration Rate: 0.15
# Game Episode : 379/500, Score: 9, Exploration Rate: 0.15
# Game Episode : 380/500, Score: 9, Exploration Rate: 0.15
# Game Episode : 381/500, Score: 42, Exploration Rate: 0.15
# Game Episode : 382/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 383/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 384/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 385/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 386/500, Score: 199, Exploration Rate: 0.15
# Game Episode : 387/500, Score: 7, Exploration Rate: 0.15
# Game Episode : 388/500, Score: 184, Exploration Rate: 0.14
# Game Episode : 389/500, Score: 199, Exploration Rate: 0.14
# Game Episode : 390/500, Score: 199, Exploration Rate: 0.14
# Game Episode : 391/500, Score: 173, Exploration Rate: 0.14
# Game Episode : 392/500, Score: 199, Exploration Rate: 0.14
# Game Episode : 393/500, Score: 184, Exploration Rate: 0.14
# Game Episode : 394/500, Score: 169, Exploration Rate: 0.14
# Game Episode : 395/500, Score: 191, Exploration Rate: 0.14
# Game Episode : 396/500, Score: 186, Exploration Rate: 0.14
# Game Episode : 397/500, Score: 190, Exploration Rate: 0.14
# Game Episode : 398/500, Score: 171, Exploration Rate: 0.14
# Game Episode : 399/500, Score: 176, Exploration Rate: 0.14
# Game Episode : 400/500, Score: 141, Exploration Rate: 0.14
# Game Episode : 401/500, Score: 180, Exploration Rate: 0.14
# Game Episode : 402/500, Score: 182, Exploration Rate: 0.13
# Game Episode : 403/500, Score: 169, Exploration Rate: 0.13
# Game Episode : 404/500, Score: 171, Exploration Rate: 0.13
# Game Episode : 405/500, Score: 157, Exploration Rate: 0.13
# Game Episode : 406/500, Score: 147, Exploration Rate: 0.13
# Game Episode : 407/500, Score: 173, Exploration Rate: 0.13
# Game Episode : 408/500, Score: 166, Exploration Rate: 0.13
# Game Episode : 409/500, Score: 158, Exploration Rate: 0.13
# Game Episode : 410/500, Score: 199, Exploration Rate: 0.13
# Game Episode : 411/500, Score: 175, Exploration Rate: 0.13
# Game Episode : 412/500, Score: 161, Exploration Rate: 0.13
# Game Episode : 413/500, Score: 188, Exploration Rate: 0.13
# Game Episode : 414/500, Score: 167, Exploration Rate: 0.13
# Game Episode : 415/500, Score: 150, Exploration Rate: 0.13
# Game Episode : 416/500, Score: 165, Exploration Rate: 0.13
# Game Episode : 417/500, Score: 166, Exploration Rate: 0.12
# Game Episode : 418/500, Score: 199, Exploration Rate: 0.12
# Game Episode : 419/500, Score: 176, Exploration Rate: 0.12
# Game Episode : 420/500, Score: 158, Exploration Rate: 0.12
# Game Episode : 421/500, Score: 144, Exploration Rate: 0.12
# Game Episode : 422/500, Score: 149, Exploration Rate: 0.12
# Game Episode : 423/500, Score: 159, Exploration Rate: 0.12
# Game Episode : 424/500, Score: 153, Exploration Rate: 0.12
# Game Episode : 425/500, Score: 155, Exploration Rate: 0.12
# Game Episode : 426/500, Score: 199, Exploration Rate: 0.12
# Game Episode : 427/500, Score: 199, Exploration Rate: 0.12
# Game Episode : 428/500, Score: 148, Exploration Rate: 0.12
# Game Episode : 429/500, Score: 131, Exploration Rate: 0.12
# Game Episode : 430/500, Score: 144, Exploration Rate: 0.12
# Game Episode : 431/500, Score: 131, Exploration Rate: 0.12
# Game Episode : 432/500, Score: 157, Exploration Rate: 0.12
# Game Episode : 433/500, Score: 110, Exploration Rate: 0.12
# Game Episode : 434/500, Score: 29, Exploration Rate: 0.11
# Game Episode : 435/500, Score: 150, Exploration Rate: 0.11
# Game Episode : 436/500, Score: 130, Exploration Rate: 0.11
# Game Episode : 437/500, Score: 123, Exploration Rate: 0.11
# Game Episode : 438/500, Score: 124, Exploration Rate: 0.11
# Game Episode : 439/500, Score: 116, Exploration Rate: 0.11
# Game Episode : 440/500, Score: 122, Exploration Rate: 0.11
# Game Episode : 441/500, Score: 121, Exploration Rate: 0.11
# Game Episode : 442/500, Score: 133, Exploration Rate: 0.11
# Game Episode : 443/500, Score: 140, Exploration Rate: 0.11
# Game Episode : 444/500, Score: 123, Exploration Rate: 0.11
# Game Episode : 445/500, Score: 120, Exploration Rate: 0.11
# Game Episode : 446/500, Score: 116, Exploration Rate: 0.11
# Game Episode : 447/500, Score: 133, Exploration Rate: 0.11
# Game Episode : 448/500, Score: 140, Exploration Rate: 0.11
# Game Episode : 449/500, Score: 129, Exploration Rate: 0.11
# Game Episode : 450/500, Score: 115, Exploration Rate: 0.11
# Game Episode : 451/500, Score: 112, Exploration Rate: 0.11
# Game Episode : 452/500, Score: 111, Exploration Rate: 0.10
# Game Episode : 453/500, Score: 139, Exploration Rate: 0.10
# Game Episode : 454/500, Score: 153, Exploration Rate: 0.10
# Game Episode : 455/500, Score: 126, Exploration Rate: 0.10
# Game Episode : 456/500, Score: 127, Exploration Rate: 0.10
# Game Episode : 457/500, Score: 125, Exploration Rate: 0.10
# Game Episode : 458/500, Score: 124, Exploration Rate: 0.10
# Game Episode : 459/500, Score: 123, Exploration Rate: 0.10
# Game Episode : 460/500, Score: 199, Exploration Rate: 0.10
# Game Episode : 461/500, Score: 199, Exploration Rate: 0.10
# Game Episode : 462/500, Score: 182, Exploration Rate: 0.10
# Game Episode : 463/500, Score: 178, Exploration Rate: 0.10
# Game Episode : 464/500, Score: 137, Exploration Rate: 0.10
# Game Episode : 465/500, Score: 167, Exploration Rate: 0.10
# Game Episode : 466/500, Score: 166, Exploration Rate: 0.10
# Game Episode : 467/500, Score: 136, Exploration Rate: 0.10
# Game Episode : 468/500, Score: 199, Exploration Rate: 0.10
# Game Episode : 469/500, Score: 135, Exploration Rate: 0.10
# Game Episode : 470/500, Score: 199, Exploration Rate: 0.10
# Game Episode : 471/500, Score: 89, Exploration Rate: 0.10
# Game Episode : 472/500, Score: 136, Exploration Rate: 0.09
# Game Episode : 473/500, Score: 31, Exploration Rate: 0.09
# Game Episode : 474/500, Score: 150, Exploration Rate: 0.09
# Game Episode : 475/500, Score: 167, Exploration Rate: 0.09
# Game Episode : 476/500, Score: 144, Exploration Rate: 0.09
# Game Episode : 477/500, Score: 147, Exploration Rate: 0.09
# Game Episode : 478/500, Score: 141, Exploration Rate: 0.09
# Game Episode : 479/500, Score: 120, Exploration Rate: 0.09
# Game Episode : 480/500, Score: 193, Exploration Rate: 0.09
# Game Episode : 481/500, Score: 159, Exploration Rate: 0.09
# Game Episode : 482/500, Score: 128, Exploration Rate: 0.09
# Game Episode : 483/500, Score: 156, Exploration Rate: 0.09
# Game Episode : 484/500, Score: 105, Exploration Rate: 0.09
# Game Episode : 485/500, Score: 134, Exploration Rate: 0.09
# Game Episode : 486/500, Score: 131, Exploration Rate: 0.09
# Game Episode : 487/500, Score: 161, Exploration Rate: 0.09
# Game Episode : 488/500, Score: 164, Exploration Rate: 0.09
# Game Episode : 489/500, Score: 199, Exploration Rate: 0.09
# Game Episode : 490/500, Score: 199, Exploration Rate: 0.09
# Game Episode : 491/500, Score: 194, Exploration Rate: 0.09
# Game Episode : 492/500, Score: 199, Exploration Rate: 0.09
# Game Episode : 493/500, Score: 199, Exploration Rate: 0.09
# Game Episode : 494/500, Score: 199, Exploration Rate: 0.08
# Game Episode : 495/500, Score: 199, Exploration Rate: 0.08
# Game Episode : 496/500, Score: 95, Exploration Rate: 0.08
# Game Episode : 497/500, Score: 199, Exploration Rate: 0.08
# Game Episode : 498/500, Score: 193, Exploration Rate: 0.08
# Game Episode : 499/500, Score: 199, Exploration Rate: 0.08
# Deep Q-Learnner Model Trained
