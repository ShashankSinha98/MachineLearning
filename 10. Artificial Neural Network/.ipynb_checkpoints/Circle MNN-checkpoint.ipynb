# %%
import numpy as np

# %%
class NeuralNetwork:
    
    def __init__(self,input_size,layers,output_size):
        np.random.seed(0)
        
        model = {} # dictionary
        
        # First Layer
        model['W1'] = np.random.randn(input_size,layers[0])
        model['b1'] = np.zeros((1,layers[0]))
        
        # Second Layer
        model['W2'] = np.random.randn(layers[0],layers[1])
        model['b2'] = np.zeros((1,layers[1]))
        
        # Third Layer
        model['W3'] = np.random.randn(layers[1],output_size)
        model['b3'] = np.zeros((1,output_size))
        
        self.model = model 
        
        
    def forward(self,x):
        
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        b1,b2,b3 = self.model['b1'],self.model['b2'],self.model['b3']
        
        z1 = np.dot(x,W1) + b1
        a1 = np.tanh(z1)
        
        z2 = np.dot(a1,W2) + b2
        a2 = np.tanh(z2)
        
        z3 = np.dot(a2,W3) + b3
        y_ = softmax(z3)
        
        self.activation_outputs = (a1,a2,y_)
        return y_
    
    def backward(self,x,y,learning_rate=0.001):
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        b1,b2,b3 = self.model['b1'],self.model['b2'],self.model['b3']
        a1,a2,y_ = self.activation_outputs
        m = x.shape[0]
    
        delta3 = y_ - y
        dw3 = np.dot(a2.T,delta3)/float(m)
        db3 = np.sum(delta3,axis=0)/float(m)

        delta2 = (1-np.square(a2))*np.dot(delta3,W3.T)
        dw2 = np.dot(a1.T,delta2)/float(m)
        db2 = np.sum(delta2,axis=0)/float(m)

        delta1 = (1-np.square(a1))*np.dot(delta2,W2.T)
        dw1 = np.dot(X.T,delta1)/float(m)
        db1 = np.sum(delta1,axis=0)/float(m)
        
        # Update the model parameter using Gradient Descent
        self.model['W1'] -= learning_rate*dw1
        self.model['b1'] -= learning_rate*db1

        self.model['W2'] -= learning_rate*dw2
        self.model['b2'] -= learning_rate*db2

        self.model['W3'] -= learning_rate*dw3
        self.model['b3'] -= learning_rate*db3

    
    def predict(self,x):
        y_out = self.forward(x)
        return np.argmax(y_out,axis=1)


    def summary(self):
        W1,W2,W3 = self.model['W1'],self.model['W2'],self.model['W3']
        a1,a2,y_ = self.activation_outputs

        print("W1",W1.shape)
        print("A1",a1.shape)

        print("W2",W2.shape)
        print("A2",a2.shape)

        print("W3",W3.shape)
        print("Y_",y_.shape)

# %%
def loss(y_oht, p):
    l = -np.mean(y_oht*np.log(p))
    return l

def one_hot(y,depth):
    m = y.shape[0]
    y_oht = np.zeros((m,depth))
    y_oht[np.arange(m),y] = 1
    return y_oht
    
def softmax(a):
    e_pa = np.exp(a)
    ans = e_pa/np.sum(e_pa,axis=1,keepdims=True)
    return ans

# %%
## Generate Dataset
from sklearn.datasets import make_circles, make_moons,make_classification
import matplotlib.pyplot as plt

# %%
def load_datasets

# %%
plt.style.use('seaborn')
plt.scatter(X[:,0],X[:,1],c=Y,cmap=plt.cm.Accent)
plt.show()

# %%
print(Y.shape)
# Out:
# (500,)

# %%
def train(X,Y,model,epochs,learning_rate,logs=True):
    training_loss = []
    
    classes = 2
    Y_OHT = one_hot(Y,classes)
    for ix in range(epochs):
        
        Y_ = model.forward(X)
        l = loss(Y_OHT,Y_)
        training_loss.append(l)
        model.backward(X,Y_OHT,learning_rate)
        
        if(logs):
            print("Epoch %d Loss %.4f"%(ix,l))
            
    return training_loss

# %%
#Training Model
model = NeuralNetwork(input_size=2,layers=[10,5],output_size=2)
losses = train(X,Y,model,1000,0.05,True)
# Out:
# Epoch 0 Loss 0.3571
# Epoch 1 Loss 0.3316
# Epoch 2 Loss 0.3182
# Epoch 3 Loss 0.3102
# Epoch 4 Loss 0.3047
# Epoch 5 Loss 0.3004
# Epoch 6 Loss 0.2968
# Epoch 7 Loss 0.2935
# Epoch 8 Loss 0.2904
# Epoch 9 Loss 0.2876
# Epoch 10 Loss 0.2848
# Epoch 11 Loss 0.2822
# Epoch 12 Loss 0.2796
# Epoch 13 Loss 0.2772
# Epoch 14 Loss 0.2747
# Epoch 15 Loss 0.2724
# Epoch 16 Loss 0.2701
# Epoch 17 Loss 0.2679
# Epoch 18 Loss 0.2657
# Epoch 19 Loss 0.2636
# Epoch 20 Loss 0.2616
# Epoch 21 Loss 0.2595
# Epoch 22 Loss 0.2576
# Epoch 23 Loss 0.2556
# Epoch 24 Loss 0.2537
# Epoch 25 Loss 0.2519
# Epoch 26 Loss 0.2500
# Epoch 27 Loss 0.2482
# Epoch 28 Loss 0.2465
# Epoch 29 Loss 0.2447
# Epoch 30 Loss 0.2430
# Epoch 31 Loss 0.2414
# Epoch 32 Loss 0.2397
# Epoch 33 Loss 0.2381
# Epoch 34 Loss 0.2365
# Epoch 35 Loss 0.2349
# Epoch 36 Loss 0.2334
# Epoch 37 Loss 0.2319
# Epoch 38 Loss 0.2304
# Epoch 39 Loss 0.2289
# Epoch 40 Loss 0.2274
# Epoch 41 Loss 0.2260
# Epoch 42 Loss 0.2246
# Epoch 43 Loss 0.2232
# Epoch 44 Loss 0.2218
# Epoch 45 Loss 0.2204
# Epoch 46 Loss 0.2191
# Epoch 47 Loss 0.2177
# Epoch 48 Loss 0.2164
# Epoch 49 Loss 0.2151
# Epoch 50 Loss 0.2138
# Epoch 51 Loss 0.2126
# Epoch 52 Loss 0.2113
# Epoch 53 Loss 0.2101
# Epoch 54 Loss 0.2088
# Epoch 55 Loss 0.2076
# Epoch 56 Loss 0.2064
# Epoch 57 Loss 0.2052
# Epoch 58 Loss 0.2041
# Epoch 59 Loss 0.2029
# Epoch 60 Loss 0.2018
# Epoch 61 Loss 0.2006
# Epoch 62 Loss 0.1995
# Epoch 63 Loss 0.1984
# Epoch 64 Loss 0.1973
# Epoch 65 Loss 0.1962
# Epoch 66 Loss 0.1951
# Epoch 67 Loss 0.1941
# Epoch 68 Loss 0.1930
# Epoch 69 Loss 0.1920
# Epoch 70 Loss 0.1909
# Epoch 71 Loss 0.1899
# Epoch 72 Loss 0.1889
# Epoch 73 Loss 0.1879
# Epoch 74 Loss 0.1869
# Epoch 75 Loss 0.1859
# Epoch 76 Loss 0.1850
# Epoch 77 Loss 0.1840
# Epoch 78 Loss 0.1830
# Epoch 79 Loss 0.1821
# Epoch 80 Loss 0.1812
# Epoch 81 Loss 0.1802
# Epoch 82 Loss 0.1793
# Epoch 83 Loss 0.1784
# Epoch 84 Loss 0.1775
# Epoch 85 Loss 0.1766
# Epoch 86 Loss 0.1758
# Epoch 87 Loss 0.1749
# Epoch 88 Loss 0.1740
# Epoch 89 Loss 0.1732
# Epoch 90 Loss 0.1723
# Epoch 91 Loss 0.1715
# Epoch 92 Loss 0.1707
# Epoch 93 Loss 0.1699
# Epoch 94 Loss 0.1690
# Epoch 95 Loss 0.1682
# Epoch 96 Loss 0.1674
# Epoch 97 Loss 0.1667
# Epoch 98 Loss 0.1659
# Epoch 99 Loss 0.1651
# Epoch 100 Loss 0.1643
# Epoch 101 Loss 0.1636
# Epoch 102 Loss 0.1628
# Epoch 103 Loss 0.1621
# Epoch 104 Loss 0.1613
# Epoch 105 Loss 0.1606
# Epoch 106 Loss 0.1599
# Epoch 107 Loss 0.1592
# Epoch 108 Loss 0.1585
# Epoch 109 Loss 0.1578
# Epoch 110 Loss 0.1571
# Epoch 111 Loss 0.1564
# Epoch 112 Loss 0.1557
# Epoch 113 Loss 0.1550
# Epoch 114 Loss 0.1543
# Epoch 115 Loss 0.1537
# Epoch 116 Loss 0.1530
# Epoch 117 Loss 0.1524
# Epoch 118 Loss 0.1517
# Epoch 119 Loss 0.1511
# Epoch 120 Loss 0.1505
# Epoch 121 Loss 0.1498
# Epoch 122 Loss 0.1492
# Epoch 123 Loss 0.1486
# Epoch 124 Loss 0.1480
# Epoch 125 Loss 0.1474
# Epoch 126 Loss 0.1468
# Epoch 127 Loss 0.1462
# Epoch 128 Loss 0.1456
# Epoch 129 Loss 0.1450
# Epoch 130 Loss 0.1444
# Epoch 131 Loss 0.1439
# Epoch 132 Loss 0.1433
# Epoch 133 Loss 0.1427
# Epoch 134 Loss 0.1422
# Epoch 135 Loss 0.1416
# Epoch 136 Loss 0.1411
# Epoch 137 Loss 0.1405
# Epoch 138 Loss 0.1400
# Epoch 139 Loss 0.1395
# Epoch 140 Loss 0.1389
# Epoch 141 Loss 0.1384
# Epoch 142 Loss 0.1379
# Epoch 143 Loss 0.1374
# Epoch 144 Loss 0.1369
# Epoch 145 Loss 0.1364
# Epoch 146 Loss 0.1359
# Epoch 147 Loss 0.1354
# Epoch 148 Loss 0.1349
# Epoch 149 Loss 0.1344
# Epoch 150 Loss 0.1339
# Epoch 151 Loss 0.1334
# Epoch 152 Loss 0.1330
# Epoch 153 Loss 0.1325
# Epoch 154 Loss 0.1320
# Epoch 155 Loss 0.1316
# Epoch 156 Loss 0.1311
# Epoch 157 Loss 0.1306
# Epoch 158 Loss 0.1302
# Epoch 159 Loss 0.1297
# Epoch 160 Loss 0.1293
# Epoch 161 Loss 0.1289
# Epoch 162 Loss 0.1284
# Epoch 163 Loss 0.1280
# Epoch 164 Loss 0.1276
# Epoch 165 Loss 0.1271
# Epoch 166 Loss 0.1267
# Epoch 167 Loss 0.1263
# Epoch 168 Loss 0.1259
# Epoch 169 Loss 0.1255
# Epoch 170 Loss 0.1251
# Epoch 171 Loss 0.1247
# Epoch 172 Loss 0.1243
# Epoch 173 Loss 0.1239
# Epoch 174 Loss 0.1235
# Epoch 175 Loss 0.1231
# Epoch 176 Loss 0.1227
# Epoch 177 Loss 0.1223
# Epoch 178 Loss 0.1219
# Epoch 179 Loss 0.1216
# Epoch 180 Loss 0.1212
# Epoch 181 Loss 0.1208
# Epoch 182 Loss 0.1205
# Epoch 183 Loss 0.1201
# Epoch 184 Loss 0.1197
# Epoch 185 Loss 0.1194
# Epoch 186 Loss 0.1190
# Epoch 187 Loss 0.1187
# Epoch 188 Loss 0.1183
# Epoch 189 Loss 0.1180
# Epoch 190 Loss 0.1176
# Epoch 191 Loss 0.1173
# Epoch 192 Loss 0.1169
# Epoch 193 Loss 0.1166
# Epoch 194 Loss 0.1163
# Epoch 195 Loss 0.1159
# Epoch 196 Loss 0.1156
# Epoch 197 Loss 0.1153
# Epoch 198 Loss 0.1149
# Epoch 199 Loss 0.1146
# Epoch 200 Loss 0.1143
# Epoch 201 Loss 0.1140
# Epoch 202 Loss 0.1137
# Epoch 203 Loss 0.1134
# Epoch 204 Loss 0.1130
# Epoch 205 Loss 0.1127
# Epoch 206 Loss 0.1124
# Epoch 207 Loss 0.1121
# Epoch 208 Loss 0.1118
# Epoch 209 Loss 0.1115
# Epoch 210 Loss 0.1112
# Epoch 211 Loss 0.1109
# Epoch 212 Loss 0.1106
# Epoch 213 Loss 0.1104
# Epoch 214 Loss 0.1101
# Epoch 215 Loss 0.1098
# Epoch 216 Loss 0.1095
# Epoch 217 Loss 0.1092
# Epoch 218 Loss 0.1089
# Epoch 219 Loss 0.1087
# Epoch 220 Loss 0.1084
# Epoch 221 Loss 0.1081
# Epoch 222 Loss 0.1078
# Epoch 223 Loss 0.1076
# Epoch 224 Loss 0.1073
# Epoch 225 Loss 0.1070
# Epoch 226 Loss 0.1068
# Epoch 227 Loss 0.1065
# Epoch 228 Loss 0.1062
# Epoch 229 Loss 0.1060
# Epoch 230 Loss 0.1057
# Epoch 231 Loss 0.1055
# Epoch 232 Loss 0.1052
# Epoch 233 Loss 0.1050
# Epoch 234 Loss 0.1047
# Epoch 235 Loss 0.1045
# Epoch 236 Loss 0.1042
# Epoch 237 Loss 0.1040
# Epoch 238 Loss 0.1037
# Epoch 239 Loss 0.1035
# Epoch 240 Loss 0.1033
# Epoch 241 Loss 0.1030
# Epoch 242 Loss 0.1028
# Epoch 243 Loss 0.1026
# Epoch 244 Loss 0.1023
# Epoch 245 Loss 0.1021
# Epoch 246 Loss 0.1019
# Epoch 247 Loss 0.1016
# Epoch 248 Loss 0.1014
# Epoch 249 Loss 0.1012
# Epoch 250 Loss 0.1010
# Epoch 251 Loss 0.1007
# Epoch 252 Loss 0.1005
# Epoch 253 Loss 0.1003
# Epoch 254 Loss 0.1001
# Epoch 255 Loss 0.0999
# Epoch 256 Loss 0.0996
# Epoch 257 Loss 0.0994
# Epoch 258 Loss 0.0992
# Epoch 259 Loss 0.0990
# Epoch 260 Loss 0.0988
# Epoch 261 Loss 0.0986
# Epoch 262 Loss 0.0984
# Epoch 263 Loss 0.0982
# Epoch 264 Loss 0.0980
# Epoch 265 Loss 0.0978
# Epoch 266 Loss 0.0976
# Epoch 267 Loss 0.0974
# Epoch 268 Loss 0.0972
# Epoch 269 Loss 0.0970
# Epoch 270 Loss 0.0968
# Epoch 271 Loss 0.0966
# Epoch 272 Loss 0.0964
# Epoch 273 Loss 0.0962
# Epoch 274 Loss 0.0960
# Epoch 275 Loss 0.0958
# Epoch 276 Loss 0.0956
# Epoch 277 Loss 0.0954
# Epoch 278 Loss 0.0953
# Epoch 279 Loss 0.0951
# Epoch 280 Loss 0.0949
# Epoch 281 Loss 0.0947
# Epoch 282 Loss 0.0945
# Epoch 283 Loss 0.0943
# Epoch 284 Loss 0.0942
# Epoch 285 Loss 0.0940
# Epoch 286 Loss 0.0938
# Epoch 287 Loss 0.0936
# Epoch 288 Loss 0.0934
# Epoch 289 Loss 0.0933
# Epoch 290 Loss 0.0931
# Epoch 291 Loss 0.0929
# Epoch 292 Loss 0.0927
# Epoch 293 Loss 0.0926
# Epoch 294 Loss 0.0924
# Epoch 295 Loss 0.0922
# Epoch 296 Loss 0.0921
# Epoch 297 Loss 0.0919
# Epoch 298 Loss 0.0917
# Epoch 299 Loss 0.0916
# Epoch 300 Loss 0.0914
# Epoch 301 Loss 0.0912
# Epoch 302 Loss 0.0911
# Epoch 303 Loss 0.0909
# Epoch 304 Loss 0.0908
# Epoch 305 Loss 0.0906
# Epoch 306 Loss 0.0904
# Epoch 307 Loss 0.0903
# Epoch 308 Loss 0.0901
# Epoch 309 Loss 0.0900
# Epoch 310 Loss 0.0898
# Epoch 311 Loss 0.0897
# Epoch 312 Loss 0.0895
# Epoch 313 Loss 0.0894
# Epoch 314 Loss 0.0892
# Epoch 315 Loss 0.0891
# Epoch 316 Loss 0.0889
# Epoch 317 Loss 0.0888
# Epoch 318 Loss 0.0886
# Epoch 319 Loss 0.0885
# Epoch 320 Loss 0.0883
# Epoch 321 Loss 0.0882
# Epoch 322 Loss 0.0880
# Epoch 323 Loss 0.0879
# Epoch 324 Loss 0.0877
# Epoch 325 Loss 0.0876
# Epoch 326 Loss 0.0875
# Epoch 327 Loss 0.0873
# Epoch 328 Loss 0.0872
# Epoch 329 Loss 0.0870
# Epoch 330 Loss 0.0869
# Epoch 331 Loss 0.0868
# Epoch 332 Loss 0.0866
# Epoch 333 Loss 0.0865
# Epoch 334 Loss 0.0863
# Epoch 335 Loss 0.0862
# Epoch 336 Loss 0.0861
# Epoch 337 Loss 0.0859
# Epoch 338 Loss 0.0858
# Epoch 339 Loss 0.0857
# Epoch 340 Loss 0.0855
# Epoch 341 Loss 0.0854
# Epoch 342 Loss 0.0853
# Epoch 343 Loss 0.0852
# Epoch 344 Loss 0.0850
# Epoch 345 Loss 0.0849
# Epoch 346 Loss 0.0848
# Epoch 347 Loss 0.0846
# Epoch 348 Loss 0.0845
# Epoch 349 Loss 0.0844
# Epoch 350 Loss 0.0843
# Epoch 351 Loss 0.0841
# Epoch 352 Loss 0.0840
# Epoch 353 Loss 0.0839
# Epoch 354 Loss 0.0838
# Epoch 355 Loss 0.0836
# Epoch 356 Loss 0.0835
# Epoch 357 Loss 0.0834
# Epoch 358 Loss 0.0833
# Epoch 359 Loss 0.0832
# Epoch 360 Loss 0.0830
# Epoch 361 Loss 0.0829
# Epoch 362 Loss 0.0828
# Epoch 363 Loss 0.0827
# Epoch 364 Loss 0.0826
# Epoch 365 Loss 0.0825
# Epoch 366 Loss 0.0823
# Epoch 367 Loss 0.0822
# Epoch 368 Loss 0.0821
# Epoch 369 Loss 0.0820
# Epoch 370 Loss 0.0819
# Epoch 371 Loss 0.0818
# Epoch 372 Loss 0.0817
# Epoch 373 Loss 0.0816
# Epoch 374 Loss 0.0814
# Epoch 375 Loss 0.0813
# Epoch 376 Loss 0.0812
# Epoch 377 Loss 0.0811
# Epoch 378 Loss 0.0810
# Epoch 379 Loss 0.0809
# Epoch 380 Loss 0.0808
# Epoch 381 Loss 0.0807
# Epoch 382 Loss 0.0806
# Epoch 383 Loss 0.0805
# Epoch 384 Loss 0.0804
# Epoch 385 Loss 0.0803
# Epoch 386 Loss 0.0802
# Epoch 387 Loss 0.0800
# Epoch 388 Loss 0.0799
# Epoch 389 Loss 0.0798
# Epoch 390 Loss 0.0797
# Epoch 391 Loss 0.0796
# Epoch 392 Loss 0.0795
# Epoch 393 Loss 0.0794
# Epoch 394 Loss 0.0793
# Epoch 395 Loss 0.0792
# Epoch 396 Loss 0.0791
# Epoch 397 Loss 0.0790
# Epoch 398 Loss 0.0789
# Epoch 399 Loss 0.0788
# Epoch 400 Loss 0.0787
# Epoch 401 Loss 0.0786
# Epoch 402 Loss 0.0785
# Epoch 403 Loss 0.0784
# Epoch 404 Loss 0.0783
# Epoch 405 Loss 0.0782
# Epoch 406 Loss 0.0782
# Epoch 407 Loss 0.0781
# Epoch 408 Loss 0.0780
# Epoch 409 Loss 0.0779
# Epoch 410 Loss 0.0778
# Epoch 411 Loss 0.0777
# Epoch 412 Loss 0.0776
# Epoch 413 Loss 0.0775
# Epoch 414 Loss 0.0774
# Epoch 415 Loss 0.0773
# Epoch 416 Loss 0.0772
# Epoch 417 Loss 0.0771
# Epoch 418 Loss 0.0770
# Epoch 419 Loss 0.0769
# Epoch 420 Loss 0.0769
# Epoch 421 Loss 0.0768
# Epoch 422 Loss 0.0767
# Epoch 423 Loss 0.0766
# Epoch 424 Loss 0.0765
# Epoch 425 Loss 0.0764
# Epoch 426 Loss 0.0763
# Epoch 427 Loss 0.0762
# Epoch 428 Loss 0.0762
# Epoch 429 Loss 0.0761
# Epoch 430 Loss 0.0760
# Epoch 431 Loss 0.0759
# Epoch 432 Loss 0.0758
# Epoch 433 Loss 0.0757
# Epoch 434 Loss 0.0756
# Epoch 435 Loss 0.0756
# Epoch 436 Loss 0.0755
# Epoch 437 Loss 0.0754
# Epoch 438 Loss 0.0753
# Epoch 439 Loss 0.0752
# Epoch 440 Loss 0.0751
# Epoch 441 Loss 0.0751
# Epoch 442 Loss 0.0750
# Epoch 443 Loss 0.0749
# Epoch 444 Loss 0.0748
# Epoch 445 Loss 0.0747
# Epoch 446 Loss 0.0746
# Epoch 447 Loss 0.0746
# Epoch 448 Loss 0.0745
# Epoch 449 Loss 0.0744
# Epoch 450 Loss 0.0743
# Epoch 451 Loss 0.0743
# Epoch 452 Loss 0.0742
# Epoch 453 Loss 0.0741
# Epoch 454 Loss 0.0740
# Epoch 455 Loss 0.0739
# Epoch 456 Loss 0.0739
# Epoch 457 Loss 0.0738
# Epoch 458 Loss 0.0737
# Epoch 459 Loss 0.0736
# Epoch 460 Loss 0.0736
# Epoch 461 Loss 0.0735
# Epoch 462 Loss 0.0734
# Epoch 463 Loss 0.0733
# Epoch 464 Loss 0.0733
# Epoch 465 Loss 0.0732
# Epoch 466 Loss 0.0731
# Epoch 467 Loss 0.0730
# Epoch 468 Loss 0.0730
# Epoch 469 Loss 0.0729
# Epoch 470 Loss 0.0728
# Epoch 471 Loss 0.0727
# Epoch 472 Loss 0.0727
# Epoch 473 Loss 0.0726
# Epoch 474 Loss 0.0725
# Epoch 475 Loss 0.0725
# Epoch 476 Loss 0.0724
# Epoch 477 Loss 0.0723
# Epoch 478 Loss 0.0722
# Epoch 479 Loss 0.0722
# Epoch 480 Loss 0.0721
# Epoch 481 Loss 0.0720
# Epoch 482 Loss 0.0720
# Epoch 483 Loss 0.0719
# Epoch 484 Loss 0.0718
# Epoch 485 Loss 0.0717
# Epoch 486 Loss 0.0717
# Epoch 487 Loss 0.0716
# Epoch 488 Loss 0.0715
# Epoch 489 Loss 0.0715
# Epoch 490 Loss 0.0714
# Epoch 491 Loss 0.0713
# Epoch 492 Loss 0.0713
# Epoch 493 Loss 0.0712
# Epoch 494 Loss 0.0711
# Epoch 495 Loss 0.0711
# Epoch 496 Loss 0.0710
# Epoch 497 Loss 0.0709
# Epoch 498 Loss 0.0709
# Epoch 499 Loss 0.0708
# Epoch 500 Loss 0.0707
# Epoch 501 Loss 0.0707
# Epoch 502 Loss 0.0706
# Epoch 503 Loss 0.0706
# Epoch 504 Loss 0.0705
# Epoch 505 Loss 0.0704
# Epoch 506 Loss 0.0704
# Epoch 507 Loss 0.0703
# Epoch 508 Loss 0.0702
# Epoch 509 Loss 0.0702
# Epoch 510 Loss 0.0701
# Epoch 511 Loss 0.0700
# Epoch 512 Loss 0.0700
# Epoch 513 Loss 0.0699
# Epoch 514 Loss 0.0699
# Epoch 515 Loss 0.0698
# Epoch 516 Loss 0.0697
# Epoch 517 Loss 0.0697
# Epoch 518 Loss 0.0696
# Epoch 519 Loss 0.0696
# Epoch 520 Loss 0.0695
# Epoch 521 Loss 0.0694
# Epoch 522 Loss 0.0694
# Epoch 523 Loss 0.0693
# Epoch 524 Loss 0.0693
# Epoch 525 Loss 0.0692
# Epoch 526 Loss 0.0691
# Epoch 527 Loss 0.0691
# Epoch 528 Loss 0.0690
# Epoch 529 Loss 0.0690
# Epoch 530 Loss 0.0689
# Epoch 531 Loss 0.0688
# Epoch 532 Loss 0.0688
# Epoch 533 Loss 0.0687
# Epoch 534 Loss 0.0687
# Epoch 535 Loss 0.0686
# Epoch 536 Loss 0.0686
# Epoch 537 Loss 0.0685
# Epoch 538 Loss 0.0684
# Epoch 539 Loss 0.0684
# Epoch 540 Loss 0.0683
# Epoch 541 Loss 0.0683
# Epoch 542 Loss 0.0682
# Epoch 543 Loss 0.0682
# Epoch 544 Loss 0.0681
# Epoch 545 Loss 0.0680
# Epoch 546 Loss 0.0680
# Epoch 547 Loss 0.0679
# Epoch 548 Loss 0.0679
# Epoch 549 Loss 0.0678
# Epoch 550 Loss 0.0678
# Epoch 551 Loss 0.0677
# Epoch 552 Loss 0.0677
# Epoch 553 Loss 0.0676
# Epoch 554 Loss 0.0676
# Epoch 555 Loss 0.0675
# Epoch 556 Loss 0.0675
# Epoch 557 Loss 0.0674
# Epoch 558 Loss 0.0673
# Epoch 559 Loss 0.0673
# Epoch 560 Loss 0.0672
# Epoch 561 Loss 0.0672
# Epoch 562 Loss 0.0671
# Epoch 563 Loss 0.0671
# Epoch 564 Loss 0.0670
# Epoch 565 Loss 0.0670
# Epoch 566 Loss 0.0669
# Epoch 567 Loss 0.0669
# Epoch 568 Loss 0.0668
# Epoch 569 Loss 0.0668
# Epoch 570 Loss 0.0667
# Epoch 571 Loss 0.0667
# Epoch 572 Loss 0.0666
# Epoch 573 Loss 0.0666
# Epoch 574 Loss 0.0665
# Epoch 575 Loss 0.0665
# Epoch 576 Loss 0.0664
# Epoch 577 Loss 0.0664
# Epoch 578 Loss 0.0663
# Epoch 579 Loss 0.0663
# Epoch 580 Loss 0.0662
# Epoch 581 Loss 0.0662
# Epoch 582 Loss 0.0661
# Epoch 583 Loss 0.0661
# Epoch 584 Loss 0.0660
# Epoch 585 Loss 0.0660
# Epoch 586 Loss 0.0659
# Epoch 587 Loss 0.0659
# Epoch 588 Loss 0.0658
# Epoch 589 Loss 0.0658
# Epoch 590 Loss 0.0657
# Epoch 591 Loss 0.0657
# Epoch 592 Loss 0.0656
# Epoch 593 Loss 0.0656
# Epoch 594 Loss 0.0656
# Epoch 595 Loss 0.0655
# Epoch 596 Loss 0.0655
# Epoch 597 Loss 0.0654
# Epoch 598 Loss 0.0654
# Epoch 599 Loss 0.0653
# Epoch 600 Loss 0.0653
# Epoch 601 Loss 0.0652
# Epoch 602 Loss 0.0652
# Epoch 603 Loss 0.0651
# Epoch 604 Loss 0.0651
# Epoch 605 Loss 0.0650
# Epoch 606 Loss 0.0650
# Epoch 607 Loss 0.0650
# Epoch 608 Loss 0.0649
# Epoch 609 Loss 0.0649
# Epoch 610 Loss 0.0648
# Epoch 611 Loss 0.0648
# Epoch 612 Loss 0.0647
# Epoch 613 Loss 0.0647
# Epoch 614 Loss 0.0646
# Epoch 615 Loss 0.0646
# Epoch 616 Loss 0.0646
# Epoch 617 Loss 0.0645
# Epoch 618 Loss 0.0645
# Epoch 619 Loss 0.0644
# Epoch 620 Loss 0.0644
# Epoch 621 Loss 0.0643
# Epoch 622 Loss 0.0643
# Epoch 623 Loss 0.0642
# Epoch 624 Loss 0.0642
# Epoch 625 Loss 0.0642
# Epoch 626 Loss 0.0641
# Epoch 627 Loss 0.0641
# Epoch 628 Loss 0.0640
# Epoch 629 Loss 0.0640
# Epoch 630 Loss 0.0640
# Epoch 631 Loss 0.0639
# Epoch 632 Loss 0.0639
# Epoch 633 Loss 0.0638
# Epoch 634 Loss 0.0638
# Epoch 635 Loss 0.0637
# Epoch 636 Loss 0.0637
# Epoch 637 Loss 0.0637
# Epoch 638 Loss 0.0636
# Epoch 639 Loss 0.0636
# Epoch 640 Loss 0.0635
# Epoch 641 Loss 0.0635
# Epoch 642 Loss 0.0635
# Epoch 643 Loss 0.0634
# Epoch 644 Loss 0.0634
# Epoch 645 Loss 0.0633
# Epoch 646 Loss 0.0633
# Epoch 647 Loss 0.0633
# Epoch 648 Loss 0.0632
# Epoch 649 Loss 0.0632
# Epoch 650 Loss 0.0631
# Epoch 651 Loss 0.0631
# Epoch 652 Loss 0.0631
# Epoch 653 Loss 0.0630
# Epoch 654 Loss 0.0630
# Epoch 655 Loss 0.0629
# Epoch 656 Loss 0.0629
# Epoch 657 Loss 0.0629
# Epoch 658 Loss 0.0628
# Epoch 659 Loss 0.0628
# Epoch 660 Loss 0.0627
# Epoch 661 Loss 0.0627
# Epoch 662 Loss 0.0627
# Epoch 663 Loss 0.0626
# Epoch 664 Loss 0.0626
# Epoch 665 Loss 0.0626
# Epoch 666 Loss 0.0625
# Epoch 667 Loss 0.0625
# Epoch 668 Loss 0.0624
# Epoch 669 Loss 0.0624
# Epoch 670 Loss 0.0624
# Epoch 671 Loss 0.0623
# Epoch 672 Loss 0.0623
# Epoch 673 Loss 0.0623
# Epoch 674 Loss 0.0622
# Epoch 675 Loss 0.0622
# Epoch 676 Loss 0.0621
# Epoch 677 Loss 0.0621
# Epoch 678 Loss 0.0621
# Epoch 679 Loss 0.0620
# Epoch 680 Loss 0.0620
# Epoch 681 Loss 0.0620
# Epoch 682 Loss 0.0619
# Epoch 683 Loss 0.0619
# Epoch 684 Loss 0.0619
# Epoch 685 Loss 0.0618
# Epoch 686 Loss 0.0618
# Epoch 687 Loss 0.0617
# Epoch 688 Loss 0.0617
# Epoch 689 Loss 0.0617
# Epoch 690 Loss 0.0616
# Epoch 691 Loss 0.0616
# Epoch 692 Loss 0.0616
# Epoch 693 Loss 0.0615
# Epoch 694 Loss 0.0615
# Epoch 695 Loss 0.0615
# Epoch 696 Loss 0.0614
# Epoch 697 Loss 0.0614
# Epoch 698 Loss 0.0614
# Epoch 699 Loss 0.0613
# Epoch 700 Loss 0.0613
# Epoch 701 Loss 0.0613
# Epoch 702 Loss 0.0612
# Epoch 703 Loss 0.0612
# Epoch 704 Loss 0.0612
# Epoch 705 Loss 0.0611
# Epoch 706 Loss 0.0611
# Epoch 707 Loss 0.0611
# Epoch 708 Loss 0.0610
# Epoch 709 Loss 0.0610
# Epoch 710 Loss 0.0610
# Epoch 711 Loss 0.0609
# Epoch 712 Loss 0.0609
# Epoch 713 Loss 0.0609
# Epoch 714 Loss 0.0608
# Epoch 715 Loss 0.0608
# Epoch 716 Loss 0.0608
# Epoch 717 Loss 0.0607
# Epoch 718 Loss 0.0607
# Epoch 719 Loss 0.0607
# Epoch 720 Loss 0.0606
# Epoch 721 Loss 0.0606
# Epoch 722 Loss 0.0606
# Epoch 723 Loss 0.0605
# Epoch 724 Loss 0.0605
# Epoch 725 Loss 0.0605
# Epoch 726 Loss 0.0604
# Epoch 727 Loss 0.0604
# Epoch 728 Loss 0.0604
# Epoch 729 Loss 0.0603
# Epoch 730 Loss 0.0603
# Epoch 731 Loss 0.0603
# Epoch 732 Loss 0.0602
# Epoch 733 Loss 0.0602
# Epoch 734 Loss 0.0602
# Epoch 735 Loss 0.0601
# Epoch 736 Loss 0.0601
# Epoch 737 Loss 0.0601
# Epoch 738 Loss 0.0600
# Epoch 739 Loss 0.0600
# Epoch 740 Loss 0.0600
# Epoch 741 Loss 0.0600
# Epoch 742 Loss 0.0599
# Epoch 743 Loss 0.0599
# Epoch 744 Loss 0.0599
# Epoch 745 Loss 0.0598
# Epoch 746 Loss 0.0598
# Epoch 747 Loss 0.0598
# Epoch 748 Loss 0.0597
# Epoch 749 Loss 0.0597
# Epoch 750 Loss 0.0597
# Epoch 751 Loss 0.0597
# Epoch 752 Loss 0.0596
# Epoch 753 Loss 0.0596
# Epoch 754 Loss 0.0596
# Epoch 755 Loss 0.0595
# Epoch 756 Loss 0.0595
# Epoch 757 Loss 0.0595
# Epoch 758 Loss 0.0594
# Epoch 759 Loss 0.0594
# Epoch 760 Loss 0.0594
# Epoch 761 Loss 0.0594
# Epoch 762 Loss 0.0593
# Epoch 763 Loss 0.0593
# Epoch 764 Loss 0.0593
# Epoch 765 Loss 0.0592
# Epoch 766 Loss 0.0592
# Epoch 767 Loss 0.0592
# Epoch 768 Loss 0.0592
# Epoch 769 Loss 0.0591
# Epoch 770 Loss 0.0591
# Epoch 771 Loss 0.0591
# Epoch 772 Loss 0.0590
# Epoch 773 Loss 0.0590
# Epoch 774 Loss 0.0590
# Epoch 775 Loss 0.0590
# Epoch 776 Loss 0.0589
# Epoch 777 Loss 0.0589
# Epoch 778 Loss 0.0589
# Epoch 779 Loss 0.0588
# Epoch 780 Loss 0.0588
# Epoch 781 Loss 0.0588
# Epoch 782 Loss 0.0588
# Epoch 783 Loss 0.0587
# Epoch 784 Loss 0.0587
# Epoch 785 Loss 0.0587
# Epoch 786 Loss 0.0586
# Epoch 787 Loss 0.0586
# Epoch 788 Loss 0.0586
# Epoch 789 Loss 0.0586
# Epoch 790 Loss 0.0585
# Epoch 791 Loss 0.0585
# Epoch 792 Loss 0.0585
# Epoch 793 Loss 0.0585
# Epoch 794 Loss 0.0584
# Epoch 795 Loss 0.0584
# Epoch 796 Loss 0.0584
# Epoch 797 Loss 0.0583
# Epoch 798 Loss 0.0583
# Epoch 799 Loss 0.0583
# Epoch 800 Loss 0.0583
# Epoch 801 Loss 0.0582
# Epoch 802 Loss 0.0582
# Epoch 803 Loss 0.0582
# Epoch 804 Loss 0.0582
# Epoch 805 Loss 0.0581
# Epoch 806 Loss 0.0581
# Epoch 807 Loss 0.0581
# Epoch 808 Loss 0.0581
# Epoch 809 Loss 0.0580
# Epoch 810 Loss 0.0580
# Epoch 811 Loss 0.0580
# Epoch 812 Loss 0.0580
# Epoch 813 Loss 0.0579
# Epoch 814 Loss 0.0579
# Epoch 815 Loss 0.0579
# Epoch 816 Loss 0.0578
# Epoch 817 Loss 0.0578
# Epoch 818 Loss 0.0578
# Epoch 819 Loss 0.0578
# Epoch 820 Loss 0.0577
# Epoch 821 Loss 0.0577
# Epoch 822 Loss 0.0577
# Epoch 823 Loss 0.0577
# Epoch 824 Loss 0.0576
# Epoch 825 Loss 0.0576
# Epoch 826 Loss 0.0576
# Epoch 827 Loss 0.0576
# Epoch 828 Loss 0.0575
# Epoch 829 Loss 0.0575
# Epoch 830 Loss 0.0575
# Epoch 831 Loss 0.0575
# Epoch 832 Loss 0.0574
# Epoch 833 Loss 0.0574
# Epoch 834 Loss 0.0574
# Epoch 835 Loss 0.0574
# Epoch 836 Loss 0.0573
# Epoch 837 Loss 0.0573
# Epoch 838 Loss 0.0573
# Epoch 839 Loss 0.0573
# Epoch 840 Loss 0.0573
# Epoch 841 Loss 0.0572
# Epoch 842 Loss 0.0572
# Epoch 843 Loss 0.0572
# Epoch 844 Loss 0.0572
# Epoch 845 Loss 0.0571
# Epoch 846 Loss 0.0571
# Epoch 847 Loss 0.0571
# Epoch 848 Loss 0.0571
# Epoch 849 Loss 0.0570
# Epoch 850 Loss 0.0570
# Epoch 851 Loss 0.0570
# Epoch 852 Loss 0.0570
# Epoch 853 Loss 0.0569
# Epoch 854 Loss 0.0569
# Epoch 855 Loss 0.0569
# Epoch 856 Loss 0.0569
# Epoch 857 Loss 0.0568
# Epoch 858 Loss 0.0568
# Epoch 859 Loss 0.0568
# Epoch 860 Loss 0.0568
# Epoch 861 Loss 0.0568
# Epoch 862 Loss 0.0567
# Epoch 863 Loss 0.0567
# Epoch 864 Loss 0.0567
# Epoch 865 Loss 0.0567
# Epoch 866 Loss 0.0566
# Epoch 867 Loss 0.0566
# Epoch 868 Loss 0.0566
# Epoch 869 Loss 0.0566
# Epoch 870 Loss 0.0565
# Epoch 871 Loss 0.0565
# Epoch 872 Loss 0.0565
# Epoch 873 Loss 0.0565
# Epoch 874 Loss 0.0565
# Epoch 875 Loss 0.0564
# Epoch 876 Loss 0.0564
# Epoch 877 Loss 0.0564
# Epoch 878 Loss 0.0564
# Epoch 879 Loss 0.0563
# Epoch 880 Loss 0.0563
# Epoch 881 Loss 0.0563
# Epoch 882 Loss 0.0563
# Epoch 883 Loss 0.0563
# Epoch 884 Loss 0.0562
# Epoch 885 Loss 0.0562
# Epoch 886 Loss 0.0562
# Epoch 887 Loss 0.0562
# Epoch 888 Loss 0.0561
# Epoch 889 Loss 0.0561
# Epoch 890 Loss 0.0561
# Epoch 891 Loss 0.0561
# Epoch 892 Loss 0.0561
# Epoch 893 Loss 0.0560
# Epoch 894 Loss 0.0560
# Epoch 895 Loss 0.0560
# Epoch 896 Loss 0.0560
# Epoch 897 Loss 0.0560
# Epoch 898 Loss 0.0559
# Epoch 899 Loss 0.0559
# Epoch 900 Loss 0.0559
# Epoch 901 Loss 0.0559
# Epoch 902 Loss 0.0559
# Epoch 903 Loss 0.0558
# Epoch 904 Loss 0.0558
# Epoch 905 Loss 0.0558
# Epoch 906 Loss 0.0558
# Epoch 907 Loss 0.0557
# Epoch 908 Loss 0.0557
# Epoch 909 Loss 0.0557
# Epoch 910 Loss 0.0557
# Epoch 911 Loss 0.0557
# Epoch 912 Loss 0.0556
# Epoch 913 Loss 0.0556
# Epoch 914 Loss 0.0556
# Epoch 915 Loss 0.0556
# Epoch 916 Loss 0.0556
# Epoch 917 Loss 0.0555
# Epoch 918 Loss 0.0555
# Epoch 919 Loss 0.0555
# Epoch 920 Loss 0.0555
# Epoch 921 Loss 0.0555
# Epoch 922 Loss 0.0554
# Epoch 923 Loss 0.0554
# Epoch 924 Loss 0.0554
# Epoch 925 Loss 0.0554
# Epoch 926 Loss 0.0554
# Epoch 927 Loss 0.0553
# Epoch 928 Loss 0.0553
# Epoch 929 Loss 0.0553
# Epoch 930 Loss 0.0553
# Epoch 931 Loss 0.0553
# Epoch 932 Loss 0.0552
# Epoch 933 Loss 0.0552
# Epoch 934 Loss 0.0552
# Epoch 935 Loss 0.0552
# Epoch 936 Loss 0.0552
# Epoch 937 Loss 0.0551
# Epoch 938 Loss 0.0551
# Epoch 939 Loss 0.0551
# Epoch 940 Loss 0.0551
# Epoch 941 Loss 0.0551
# Epoch 942 Loss 0.0550
# Epoch 943 Loss 0.0550
# Epoch 944 Loss 0.0550
# Epoch 945 Loss 0.0550
# Epoch 946 Loss 0.0550
# Epoch 947 Loss 0.0549
# Epoch 948 Loss 0.0549
# Epoch 949 Loss 0.0549
# Epoch 950 Loss 0.0549
# Epoch 951 Loss 0.0549
# Epoch 952 Loss 0.0548
# Epoch 953 Loss 0.0548
# Epoch 954 Loss 0.0548
# Epoch 955 Loss 0.0548
# Epoch 956 Loss 0.0548
# Epoch 957 Loss 0.0548
# Epoch 958 Loss 0.0547
# Epoch 959 Loss 0.0547
# Epoch 960 Loss 0.0547
# Epoch 961 Loss 0.0547
# Epoch 962 Loss 0.0547
# Epoch 963 Loss 0.0546
# Epoch 964 Loss 0.0546
# Epoch 965 Loss 0.0546
# Epoch 966 Loss 0.0546
# Epoch 967 Loss 0.0546
# Epoch 968 Loss 0.0546
# Epoch 969 Loss 0.0545
# Epoch 970 Loss 0.0545
# Epoch 971 Loss 0.0545
# Epoch 972 Loss 0.0545
# Epoch 973 Loss 0.0545
# Epoch 974 Loss 0.0544
# Epoch 975 Loss 0.0544
# Epoch 976 Loss 0.0544
# Epoch 977 Loss 0.0544
# Epoch 978 Loss 0.0544
# Epoch 979 Loss 0.0544
# Epoch 980 Loss 0.0543
# Epoch 981 Loss 0.0543
# Epoch 982 Loss 0.0543
# Epoch 983 Loss 0.0543
# Epoch 984 Loss 0.0543
# Epoch 985 Loss 0.0542
# Epoch 986 Loss 0.0542
# Epoch 987 Loss 0.0542
# Epoch 988 Loss 0.0542
# Epoch 989 Loss 0.0542
# Epoch 990 Loss 0.0542
# Epoch 991 Loss 0.0541
# Epoch 992 Loss 0.0541
# Epoch 993 Loss 0.0541
# Epoch 994 Loss 0.0541
# Epoch 995 Loss 0.0541
# Epoch 996 Loss 0.0541
# Epoch 997 Loss 0.0540
# Epoch 998 Loss 0.0540
# Epoch 999 Loss 0.0540

# %%
plt.plot(losses)
plt.show()

# %%
model.summary()
# Out:
# W1 (2, 10)
# A1 (500, 10)
# W2 (10, 5)
# A2 (500, 5)
# W3 (5, 2)
# Y_ (500, 2)

# %%
from visualize import plot_decision_boundary

# %%
plot_decision_boundary(lambda x:model.predict(x),X,Y)

# %%
outputs = model.predict(X)
np.sum(outputs==Y)/Y.shape[0]
# Out:
# 0.974
